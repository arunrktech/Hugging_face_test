# %%
# %pip install transformers python-dotenv
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
 pip install sentencepiece
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from dotenv import load_dotenv
import os

load_dotenv("env.txt")
print(os.getenv("HF_TOKEN"))
# Out:
# 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

# %%
from huggingface_hub import login
login()

# %%
from transformers import pipeline
pipe = pipeline("text-generation", model="unsloth/Llama-3.2-1B-Instruct")
#print(pipe("Explain Kafka consumer groups in two sentences.", max_new_tokens=100))
result = pipe("Once upon a time, there was a wise wizard who", max_length=50)
print(result)
# Out:
# Loading weights:   0%|          | 0/146 [00:00<?, ?it/s]
# [transformers] Passing `generation_config` together with generation-related arguments=({'max_length'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# [{'generated_text': 'Once upon a time, there was a wise wizard who lived in a small village surrounded by rolling hills and dense forests. The wizard was known throughout the land for his wisdom, magical powers, and his ability to communicate with animals. The villagers would'}]
